# %%
import pandas as pd
import numpy as np

# %%
cancer= pd.read_csv('cancer.csv')

# %%
cancer
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0            2013     2017           AK                Alaska
# 1            2014     2018           AK                Alaska
# 2            2009     2013           CT           Connecticut
# 3            2014     2018           CT           Connecticut
# 4            2008     2012           DC  District of Columbia
# ...           ...      ...          ...                   ...
# 176334       2020     2020           WY               Wyoming
# 176335       2020     2020           WY               Wyoming
# 176336       2020     2020           WY               Wyoming
# 176337       2020     2020           WY               Wyoming
# 176338       2020     2020           WY               Wyoming
#
#                                  DataSource   Topic  \
# 0       Statewide central cancer registries  Cancer
# 1       Statewide central cancer registries  Cancer
# 2       Statewide central cancer registries  Cancer
# 3       Statewide central cancer registries  Cancer
# 4       Statewide central cancer registries  Cancer
# ...                                     ...     ...
# 176334                                BRFSS  Cancer
# 176335                                BRFSS  Cancer
# 176336                                BRFSS  Cancer
# 176337                                BRFSS  Cancer
# 176338                                BRFSS  Cancer
#
#                                                  Question  Response  \
# 0       Invasive cancer of the oral cavity or pharynx,...       NaN
# 1       Invasive cancer of the oral cavity or pharynx,...       NaN
# 2       Invasive cancer of the oral cavity or pharynx,...       NaN
# 3       Invasive cancer of the oral cavity or pharynx,...       NaN
# 4       Invasive cancer of the oral cavity or pharynx,...       NaN
# ...                                                   ...       ...
# 176334  Papanicolaou smear use among adult women aged ...       NaN
# 176335  Fecal occult blood test, sigmoidoscopy, or col...       NaN
# 176336  Fecal occult blood test, sigmoidoscopy, or col...       NaN
# 176337       Mammography use among women aged 50-74 years       NaN
# 176338  Recent Papanicolaou smear use among women aged...       NaN
#
#        DataValueUnit            DataValueType  ...  LocationID  TopicID  \
# 0                NaN    Average Annual Number  ...           2      CAN
# 1                NaN    Average Annual Number  ...           2      CAN
# 2                NaN    Average Annual Number  ...           9      CAN
# 3                NaN    Average Annual Number  ...           9      CAN
# 4                NaN    Average Annual Number  ...          11      CAN
# ...              ...                      ...  ...         ...      ...
# 176334             %  Age-adjusted Prevalence  ...          56      CAN
# 176335             %  Age-adjusted Prevalence  ...          56      CAN
# 176336             %         Crude Prevalence  ...          56      CAN
# 176337             %         Crude Prevalence  ...          56      CAN
# 176338             %         Crude Prevalence  ...          56      CAN
#
#        QuestionID DataValueTypeID  StratificationCategoryID1  \
# 0         CAN10_1      AVGANNNMBR                     GENDER
# 1         CAN10_1      AVGANNNMBR                    OVERALL
# 2         CAN10_1      AVGANNNMBR                     GENDER
# 3         CAN10_1      AVGANNNMBR                       RACE
# 4         CAN10_1      AVGANNNMBR                    OVERALL
# ...           ...             ...                        ...
# 176334     CAN2_1      AGEADJPREV                    OVERALL
# 176335     CAN3_0      AGEADJPREV                       RACE
# 176336     CAN3_0         CRDPREV                       RACE
# 176337     CAN1_0         CRDPREV                       RACE
# 176338     CAN2_2         CRDPREV                       RACE
#
#         StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0                    GENM                       NaN               NaN
# 1                     OVR                       NaN               NaN
# 2                    GENM                       NaN               NaN
# 3                     HIS                       NaN               NaN
# 4                     OVR                       NaN               NaN
# ...                   ...                       ...               ...
# 176334                OVR                       NaN               NaN
# 176335                MRC                       NaN               NaN
# 176336                HIS                       NaN               NaN
# 176337                OTH                       NaN               NaN
# 176338                WHT                       NaN               NaN
#
#         StratificationCategoryID3  StratificationID3
# 0                             NaN                NaN
# 1                             NaN                NaN
# 2                             NaN                NaN
# 3                             NaN                NaN
# 4                             NaN                NaN
# ...                           ...                ...
# 176334                        NaN                NaN
# 176335                        NaN                NaN
# 176336                        NaN                NaN
# 176337                        NaN                NaN
# 176338                        NaN                NaN
#
# [176339 rows x 33 columns]

# %%
cancer.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'ResponseID', 'LocationID', 'TopicID', 'QuestionID', 'DataValueTypeID',
#        'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
cancer['LocationDesc'].value_counts()
# Out:
# Alaska                  3378
# Connecticut             3378
# Montana                 3378
# New Jersey              3378
# Vermont                 3378
# Washington              3378
# Wyoming                 3378
# Colorado                3378
# Florida                 3378
# Georgia                 3378
# Michigan                3378
# Nevada                  3378
# Oregon                  3378
# Tennessee               3378
# Texas                   3378
# Kansas                  3378
# Missouri                3378
# Rhode Island            3378
# Wisconsin               3378
# Iowa                    3378
# Utah                    3378
# Arkansas                3378
# Nebraska                3378
# New York                3378
# Ohio                    3378
# Mississippi             3378
# Maine                   3378
# Maryland                3378
# Minnesota               3378
# District of Columbia    3378
# Hawaii                  3378
# Idaho                   3378
# Kentucky                3378
# Louisiana               3378
# Massachusetts           3378
# New Hampshire           3378
# New Mexico              3378
# Oklahoma                3378
# Pennsylvania            3378
# Indiana                 3378
# Illinois                3378
# North Carolina          3378
# North Dakota            3378
# South Carolina          3378
# South Dakota            3378
# Virginia                3378
# West Virginia           3378
# Alabama                 3378
# Arizona                 3378
# California              3378
# Delaware                3378
# United States           3143
# Puerto Rico              306
# Guam                     306
# Virgin Islands           306
# Name: LocationDesc, dtype: int64

# %%
len(cancer['LocationDesc'])
# Out:
# 176339

# %%
len('LocationDesc')
# Out:
# 12

# %%
cancer
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0            2013     2017           AK                Alaska
# 1            2014     2018           AK                Alaska
# 2            2009     2013           CT           Connecticut
# 3            2014     2018           CT           Connecticut
# 4            2008     2012           DC  District of Columbia
# ...           ...      ...          ...                   ...
# 176334       2020     2020           WY               Wyoming
# 176335       2020     2020           WY               Wyoming
# 176336       2020     2020           WY               Wyoming
# 176337       2020     2020           WY               Wyoming
# 176338       2020     2020           WY               Wyoming
#
#                                  DataSource   Topic  \
# 0       Statewide central cancer registries  Cancer
# 1       Statewide central cancer registries  Cancer
# 2       Statewide central cancer registries  Cancer
# 3       Statewide central cancer registries  Cancer
# 4       Statewide central cancer registries  Cancer
# ...                                     ...     ...
# 176334                                BRFSS  Cancer
# 176335                                BRFSS  Cancer
# 176336                                BRFSS  Cancer
# 176337                                BRFSS  Cancer
# 176338                                BRFSS  Cancer
#
#                                                  Question  Response  \
# 0       Invasive cancer of the oral cavity or pharynx,...       NaN
# 1       Invasive cancer of the oral cavity or pharynx,...       NaN
# 2       Invasive cancer of the oral cavity or pharynx,...       NaN
# 3       Invasive cancer of the oral cavity or pharynx,...       NaN
# 4       Invasive cancer of the oral cavity or pharynx,...       NaN
# ...                                                   ...       ...
# 176334  Papanicolaou smear use among adult women aged ...       NaN
# 176335  Fecal occult blood test, sigmoidoscopy, or col...       NaN
# 176336  Fecal occult blood test, sigmoidoscopy, or col...       NaN
# 176337       Mammography use among women aged 50-74 years       NaN
# 176338  Recent Papanicolaou smear use among women aged...       NaN
#
#        DataValueUnit            DataValueType  ...  LocationID  TopicID  \
# 0                NaN    Average Annual Number  ...           2      CAN
# 1                NaN    Average Annual Number  ...           2      CAN
# 2                NaN    Average Annual Number  ...           9      CAN
# 3                NaN    Average Annual Number  ...           9      CAN
# 4                NaN    Average Annual Number  ...          11      CAN
# ...              ...                      ...  ...         ...      ...
# 176334             %  Age-adjusted Prevalence  ...          56      CAN
# 176335             %  Age-adjusted Prevalence  ...          56      CAN
# 176336             %         Crude Prevalence  ...          56      CAN
# 176337             %         Crude Prevalence  ...          56      CAN
# 176338             %         Crude Prevalence  ...          56      CAN
#
#        QuestionID DataValueTypeID  StratificationCategoryID1  \
# 0         CAN10_1      AVGANNNMBR                     GENDER
# 1         CAN10_1      AVGANNNMBR                    OVERALL
# 2         CAN10_1      AVGANNNMBR                     GENDER
# 3         CAN10_1      AVGANNNMBR                       RACE
# 4         CAN10_1      AVGANNNMBR                    OVERALL
# ...           ...             ...                        ...
# 176334     CAN2_1      AGEADJPREV                    OVERALL
# 176335     CAN3_0      AGEADJPREV                       RACE
# 176336     CAN3_0         CRDPREV                       RACE
# 176337     CAN1_0         CRDPREV                       RACE
# 176338     CAN2_2         CRDPREV                       RACE
#
#         StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0                    GENM                       NaN               NaN
# 1                     OVR                       NaN               NaN
# 2                    GENM                       NaN               NaN
# 3                     HIS                       NaN               NaN
# 4                     OVR                       NaN               NaN
# ...                   ...                       ...               ...
# 176334                OVR                       NaN               NaN
# 176335                MRC                       NaN               NaN
# 176336                HIS                       NaN               NaN
# 176337                OTH                       NaN               NaN
# 176338                WHT                       NaN               NaN
#
#         StratificationCategoryID3  StratificationID3
# 0                             NaN                NaN
# 1                             NaN                NaN
# 2                             NaN                NaN
# 3                             NaN                NaN
# 4                             NaN                NaN
# ...                           ...                ...
# 176334                        NaN                NaN
# 176335                        NaN                NaN
# 176336                        NaN                NaN
# 176337                        NaN                NaN
# 176338                        NaN                NaN
#
# [176339 rows x 33 columns]

# %%
cancer['Question'].value_counts()
# Out:
# Invasive cancer of the oral cavity or pharynx, incidence                                9984
# Invasive cancer of the cervix, incidence                                                9984
# Invasive melanoma, incidence                                                            9984
# Cancer of the lung and bronchus, mortality                                              9984
# Cancer of the lung and bronchus, incidence                                              9984
# Cancer of the colon and rectum (colorectal), mortality                                  9984
# Cancer of the colon and rectum (colorectal), incidence                                  9984
# Cancer of the oral cavity and pharynx, mortality                                        9984
# Cancer of the female cervix, mortality                                                  9984
# Cancer of the female breast, mortality                                                  9984
# Melanoma, mortality                                                                     9984
# Invasive cancer of the female breast, incidence                                         9984
# Invasive cancer (all sites combined), mortality                                         9984
# Invasive cancer (all sites combined), incidence                                         9984
# Cancer of the prostate, mortality                                                       9984
# Invasive cancer of the prostate, incidence                                              9984
# Fecal occult blood test, sigmoidoscopy, or colonoscopy among adults aged 50-75 years    5220
# Mammography use among women aged 50-74 years                                            4550
# Papanicolaou smear use among adult women aged 21-65 years                               4550
# Recent Papanicolaou smear use among women aged 21-44 years                              2275
# Name: Question, dtype: int64

# %%
cancer
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0            2013     2017           AK                Alaska
# 1            2014     2018           AK                Alaska
# 2            2009     2013           CT           Connecticut
# 3            2014     2018           CT           Connecticut
# 4            2008     2012           DC  District of Columbia
# ...           ...      ...          ...                   ...
# 176334       2020     2020           WY               Wyoming
# 176335       2020     2020           WY               Wyoming
# 176336       2020     2020           WY               Wyoming
# 176337       2020     2020           WY               Wyoming
# 176338       2020     2020           WY               Wyoming
#
#                                  DataSource   Topic  \
# 0       Statewide central cancer registries  Cancer
# 1       Statewide central cancer registries  Cancer
# 2       Statewide central cancer registries  Cancer
# 3       Statewide central cancer registries  Cancer
# 4       Statewide central cancer registries  Cancer
# ...                                     ...     ...
# 176334                                BRFSS  Cancer
# 176335                                BRFSS  Cancer
# 176336                                BRFSS  Cancer
# 176337                                BRFSS  Cancer
# 176338                                BRFSS  Cancer
#
#                                                  Question  Response  \
# 0       Invasive cancer of the oral cavity or pharynx,...       NaN
# 1       Invasive cancer of the oral cavity or pharynx,...       NaN
# 2       Invasive cancer of the oral cavity or pharynx,...       NaN
# 3       Invasive cancer of the oral cavity or pharynx,...       NaN
# 4       Invasive cancer of the oral cavity or pharynx,...       NaN
# ...                                                   ...       ...
# 176334  Papanicolaou smear use among adult women aged ...       NaN
# 176335  Fecal occult blood test, sigmoidoscopy, or col...       NaN
# 176336  Fecal occult blood test, sigmoidoscopy, or col...       NaN
# 176337       Mammography use among women aged 50-74 years       NaN
# 176338  Recent Papanicolaou smear use among women aged...       NaN
#
#        DataValueUnit            DataValueType  ...  LocationID  TopicID  \
# 0                NaN    Average Annual Number  ...           2      CAN
# 1                NaN    Average Annual Number  ...           2      CAN
# 2                NaN    Average Annual Number  ...           9      CAN
# 3                NaN    Average Annual Number  ...           9      CAN
# 4                NaN    Average Annual Number  ...          11      CAN
# ...              ...                      ...  ...         ...      ...
# 176334             %  Age-adjusted Prevalence  ...          56      CAN
# 176335             %  Age-adjusted Prevalence  ...          56      CAN
# 176336             %         Crude Prevalence  ...          56      CAN
# 176337             %         Crude Prevalence  ...          56      CAN
# 176338             %         Crude Prevalence  ...          56      CAN
#
#        QuestionID DataValueTypeID  StratificationCategoryID1  \
# 0         CAN10_1      AVGANNNMBR                     GENDER
# 1         CAN10_1      AVGANNNMBR                    OVERALL
# 2         CAN10_1      AVGANNNMBR                     GENDER
# 3         CAN10_1      AVGANNNMBR                       RACE
# 4         CAN10_1      AVGANNNMBR                    OVERALL
# ...           ...             ...                        ...
# 176334     CAN2_1      AGEADJPREV                    OVERALL
# 176335     CAN3_0      AGEADJPREV                       RACE
# 176336     CAN3_0         CRDPREV                       RACE
# 176337     CAN1_0         CRDPREV                       RACE
# 176338     CAN2_2         CRDPREV                       RACE
#
#         StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0                    GENM                       NaN               NaN
# 1                     OVR                       NaN               NaN
# 2                    GENM                       NaN               NaN
# 3                     HIS                       NaN               NaN
# 4                     OVR                       NaN               NaN
# ...                   ...                       ...               ...
# 176334                OVR                       NaN               NaN
# 176335                MRC                       NaN               NaN
# 176336                HIS                       NaN               NaN
# 176337                OTH                       NaN               NaN
# 176338                WHT                       NaN               NaN
#
#         StratificationCategoryID3  StratificationID3
# 0                             NaN                NaN
# 1                             NaN                NaN
# 2                             NaN                NaN
# 3                             NaN                NaN
# 4                             NaN                NaN
# ...                           ...                ...
# 176334                        NaN                NaN
# 176335                        NaN                NaN
# 176336                        NaN                NaN
# 176337                        NaN                NaN
# 176338                        NaN                NaN
#
# [176339 rows x 33 columns]

# %%
cancer['Response'].value_counts()
# Out:
# Series([], Name: Response, dtype: int64)

# %%
cancer.drop(columns=['Response'], inplace= True)

# %%
cancer
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0            2013     2017           AK                Alaska
# 1            2014     2018           AK                Alaska
# 2            2009     2013           CT           Connecticut
# 3            2014     2018           CT           Connecticut
# 4            2008     2012           DC  District of Columbia
# ...           ...      ...          ...                   ...
# 176334       2020     2020           WY               Wyoming
# 176335       2020     2020           WY               Wyoming
# 176336       2020     2020           WY               Wyoming
# 176337       2020     2020           WY               Wyoming
# 176338       2020     2020           WY               Wyoming
#
#                                  DataSource   Topic  \
# 0       Statewide central cancer registries  Cancer
# 1       Statewide central cancer registries  Cancer
# 2       Statewide central cancer registries  Cancer
# 3       Statewide central cancer registries  Cancer
# 4       Statewide central cancer registries  Cancer
# ...                                     ...     ...
# 176334                                BRFSS  Cancer
# 176335                                BRFSS  Cancer
# 176336                                BRFSS  Cancer
# 176337                                BRFSS  Cancer
# 176338                                BRFSS  Cancer
#
#                                                  Question DataValueUnit  \
# 0       Invasive cancer of the oral cavity or pharynx,...           NaN
# 1       Invasive cancer of the oral cavity or pharynx,...           NaN
# 2       Invasive cancer of the oral cavity or pharynx,...           NaN
# 3       Invasive cancer of the oral cavity or pharynx,...           NaN
# 4       Invasive cancer of the oral cavity or pharynx,...           NaN
# ...                                                   ...           ...
# 176334  Papanicolaou smear use among adult women aged ...             %
# 176335  Fecal occult blood test, sigmoidoscopy, or col...             %
# 176336  Fecal occult blood test, sigmoidoscopy, or col...             %
# 176337       Mammography use among women aged 50-74 years             %
# 176338  Recent Papanicolaou smear use among women aged...             %
#
#                   DataValueType  DataValue  ...  LocationID TopicID  \
# 0         Average Annual Number       62.0  ...           2     CAN
# 1         Average Annual Number       84.0  ...           2     CAN
# 2         Average Annual Number      325.0  ...           9     CAN
# 3         Average Annual Number       46.0  ...           9     CAN
# 4         Average Annual Number       73.0  ...          11     CAN
# ...                         ...        ...  ...         ...     ...
# 176334  Age-adjusted Prevalence       72.6  ...          56     CAN
# 176335  Age-adjusted Prevalence        NaN  ...          56     CAN
# 176336         Crude Prevalence       49.8  ...          56     CAN
# 176337         Crude Prevalence        NaN  ...          56     CAN
# 176338         Crude Prevalence       74.6  ...          56     CAN
#
#        QuestionID  DataValueTypeID  StratificationCategoryID1  \
# 0         CAN10_1       AVGANNNMBR                     GENDER
# 1         CAN10_1       AVGANNNMBR                    OVERALL
# 2         CAN10_1       AVGANNNMBR                     GENDER
# 3         CAN10_1       AVGANNNMBR                       RACE
# 4         CAN10_1       AVGANNNMBR                    OVERALL
# ...           ...              ...                        ...
# 176334     CAN2_1       AGEADJPREV                    OVERALL
# 176335     CAN3_0       AGEADJPREV                       RACE
# 176336     CAN3_0          CRDPREV                       RACE
# 176337     CAN1_0          CRDPREV                       RACE
# 176338     CAN2_2          CRDPREV                       RACE
#
#        StratificationID1 StratificationCategoryID2  StratificationID2  \
# 0                   GENM                       NaN                NaN
# 1                    OVR                       NaN                NaN
# 2                   GENM                       NaN                NaN
# 3                    HIS                       NaN                NaN
# 4                    OVR                       NaN                NaN
# ...                  ...                       ...                ...
# 176334               OVR                       NaN                NaN
# 176335               MRC                       NaN                NaN
# 176336               HIS                       NaN                NaN
# 176337               OTH                       NaN                NaN
# 176338               WHT                       NaN                NaN
#
#         StratificationCategoryID3  StratificationID3
# 0                             NaN                NaN
# 1                             NaN                NaN
# 2                             NaN                NaN
# 3                             NaN                NaN
# 4                             NaN                NaN
# ...                           ...                ...
# 176334                        NaN                NaN
# 176335                        NaN                NaN
# 176336                        NaN                NaN
# 176337                        NaN                NaN
# 176338                        NaN                NaN
#
# [176339 rows x 32 columns]

# %%
#print(records_prostate)

# %%
#to display the records for the prostate cancer mortality rate only for the further analysis
desired_records = cancer[cancer["Question"] == 'Cancer of the prostate, mortality']

# %%
desired_records
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc         DataSource  \
# 76          2013     2017           CA     California  Death Certificate
# 77          2014     2018           CA     California  Death Certificate
# 78          2010     2014           CO       Colorado  Death Certificate
# 79          2008     2012           FL        Florida  Death Certificate
# 80          2008     2012           GA        Georgia  Death Certificate
# ...          ...      ...          ...            ...                ...
# 52536       2009     2013           SD   South Dakota  Death Certificate
# 52545       2008     2012           VA       Virginia  Death Certificate
# 52547       2008     2012           WA     Washington  Death Certificate
# 52548       2011     2015           WV  West Virginia  Death Certificate
# 52555       2014     2018           UT           Utah  Death Certificate
#
#         Topic                           Question DataValueUnit  \
# 76     Cancer  Cancer of the prostate, mortality   per 100,000
# 77     Cancer  Cancer of the prostate, mortality           NaN
# 78     Cancer  Cancer of the prostate, mortality   per 100,000
# 79     Cancer  Cancer of the prostate, mortality           NaN
# 80     Cancer  Cancer of the prostate, mortality           NaN
# ...       ...                                ...           ...
# 52536  Cancer  Cancer of the prostate, mortality   per 100,000
# 52545  Cancer  Cancer of the prostate, mortality   per 100,000
# 52547  Cancer  Cancer of the prostate, mortality   per 100,000
# 52548  Cancer  Cancer of the prostate, mortality   per 100,000
# 52555  Cancer  Cancer of the prostate, mortality   per 100,000
#
#                           DataValueType  DataValue  ...  LocationID TopicID  \
# 76            Average Annual Crude Rate        7.1  ...           6     CAN
# 77                Average Annual Number     3469.0  ...           6     CAN
# 78            Average Annual Crude Rate        4.6  ...           8     CAN
# 79                Average Annual Number     2086.0  ...          12     CAN
# 80                Average Annual Number      750.0  ...          13     CAN
# ...                                 ...        ...  ...         ...     ...
# 52536         Average Annual Crude Rate       23.0  ...          46     CAN
# 52545  Average Annual Age-adjusted Rate        NaN  ...          51     CAN
# 52547         Average Annual Crude Rate       18.4  ...          53     CAN
# 52548         Average Annual Crude Rate       19.1  ...          54     CAN
# 52555  Average Annual Age-adjusted Rate        NaN  ...          49     CAN
#
#       QuestionID   DataValueTypeID  StratificationCategoryID1  \
# 76       CAN11_2     AVGANNCRDRATE                       RACE
# 77       CAN11_2        AVGANNNMBR                     GENDER
# 78       CAN11_2     AVGANNCRDRATE                       RACE
# 79       CAN11_2        AVGANNNMBR                     GENDER
# 80       CAN11_2        AVGANNNMBR                     GENDER
# ...          ...               ...                        ...
# 52536    CAN11_2     AVGANNCRDRATE                       RACE
# 52545    CAN11_2  AVGANNAGEADJRATE                       RACE
# 52547    CAN11_2     AVGANNCRDRATE                    OVERALL
# 52548    CAN11_2     AVGANNCRDRATE                     GENDER
# 52555    CAN11_2  AVGANNAGEADJRATE                       RACE
#
#       StratificationID1 StratificationCategoryID2  StratificationID2  \
# 76                  HIS                       NaN                NaN
# 77                 GENM                       NaN                NaN
# 78                 APIO                       NaN                NaN
# 79                 GENM                       NaN                NaN
# 80                 GENM                       NaN                NaN
# ...                 ...                       ...                ...
# 52536               WHT                       NaN                NaN
# 52545              AIAO                       NaN                NaN
# 52547               OVR                       NaN                NaN
# 52548              GENM                       NaN                NaN
# 52555               BLK                       NaN                NaN
#
#        StratificationCategoryID3  StratificationID3
# 76                           NaN                NaN
# 77                           NaN                NaN
# 78                           NaN                NaN
# 79                           NaN                NaN
# 80                           NaN                NaN
# ...                          ...                ...
# 52536                        NaN                NaN
# 52545                        NaN                NaN
# 52547                        NaN                NaN
# 52548                        NaN                NaN
# 52555                        NaN                NaN
#
# [9984 rows x 32 columns]

# %%
len(desired_records.columns)
# Out:
# 32

# %%
desired_records.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'DataValueFootnoteSymbol', 'DatavalueFootnote',
#        'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategory2', 'Stratification2',
#        'StratificationCategory3', 'Stratification3', 'ResponseID',
#        'LocationID', 'TopicID', 'QuestionID', 'DataValueTypeID',
#        'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
#creating a list to check no. of empty columns so as to drop them for convenience
desired_columns =['StratificationCategory1',
       'Stratification1', 'StratificationCategory2', 'Stratification2',
       'StratificationCategory3', 'Stratification3', 'ResponseID','StratificationCategoryID1', 'StratificationID1',
       'StratificationCategoryID2', 'StratificationID2',
       'StratificationCategoryID3', 'StratificationID3']

# %%
# Display value counts for the desired columns
for column in desired_columns:
    value_counts = desired_records[column].value_counts()
    print(f"Value counts for {column}:\n{value_counts}\n")
# Out:
# Value counts for StratificationCategory1:
# Race/Ethnicity    6240
# Gender            2496
# Overall           1248
# Name: StratificationCategory1, dtype: int64
#
# Value counts for Stratification1:
# Hispanic                            1248
# Male                                1248
# Asian or Pacific Islander           1248
# Overall                             1248
# Black, non-Hispanic                 1248
# White, non-Hispanic                 1248
# American Indian or Alaska Native    1248
# Female                              1248
# Name: Stratification1, dtype: int64
#
# Value counts for StratificationCategory2:
# Series([], Name: StratificationCategory2, dtype: int64)
#
# Value counts for Stratification2:
# Series([], Name: Stratification2, dtype: int64)
#
# Value counts for StratificationCategory3:
# Series([], Name: StratificationCategory3, dtype: int64)
#
# Value counts for Stratification3:
# Series([], Name: Stratification3, dtype: int64)
#
# Value counts for ResponseID:
# Series([], Name: ResponseID, dtype: int64)
#
# Value counts for StratificationCategoryID1:
# RACE       6240
# GENDER     2496
# OVERALL    1248
# Name: StratificationCategoryID1, dtype: int64
#
# Value counts for StratificationID1:
# HIS     1248
# GENM    1248
# APIO    1248
# OVR     1248
# BLK     1248
# WHT     1248
# AIAO    1248
# GENF    1248
# Name: StratificationID1, dtype: int64
#
# Value counts for StratificationCategoryID2:
# Series([], Name: StratificationCategoryID2, dtype: int64)
#
# Value counts for StratificationID2:
# Series([], Name: StratificationID2, dtype: int64)
#
# Value counts for StratificationCategoryID3:
# Series([], Name: StratificationCategoryID3, dtype: int64)
#
# Value counts for StratificationID3:
# Series([], Name: StratificationID3, dtype: int64)

# %%
desired_records
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc         DataSource  \
# 76          2013     2017           CA     California  Death Certificate
# 77          2014     2018           CA     California  Death Certificate
# 78          2010     2014           CO       Colorado  Death Certificate
# 79          2008     2012           FL        Florida  Death Certificate
# 80          2008     2012           GA        Georgia  Death Certificate
# ...          ...      ...          ...            ...                ...
# 52536       2009     2013           SD   South Dakota  Death Certificate
# 52545       2008     2012           VA       Virginia  Death Certificate
# 52547       2008     2012           WA     Washington  Death Certificate
# 52548       2011     2015           WV  West Virginia  Death Certificate
# 52555       2014     2018           UT           Utah  Death Certificate
#
#         Topic                           Question DataValueUnit  \
# 76     Cancer  Cancer of the prostate, mortality   per 100,000
# 77     Cancer  Cancer of the prostate, mortality           NaN
# 78     Cancer  Cancer of the prostate, mortality   per 100,000
# 79     Cancer  Cancer of the prostate, mortality           NaN
# 80     Cancer  Cancer of the prostate, mortality           NaN
# ...       ...                                ...           ...
# 52536  Cancer  Cancer of the prostate, mortality   per 100,000
# 52545  Cancer  Cancer of the prostate, mortality   per 100,000
# 52547  Cancer  Cancer of the prostate, mortality   per 100,000
# 52548  Cancer  Cancer of the prostate, mortality   per 100,000
# 52555  Cancer  Cancer of the prostate, mortality   per 100,000
#
#                           DataValueType  DataValue  ...  LocationID TopicID  \
# 76            Average Annual Crude Rate        7.1  ...           6     CAN
# 77                Average Annual Number     3469.0  ...           6     CAN
# 78            Average Annual Crude Rate        4.6  ...           8     CAN
# 79                Average Annual Number     2086.0  ...          12     CAN
# 80                Average Annual Number      750.0  ...          13     CAN
# ...                                 ...        ...  ...         ...     ...
# 52536         Average Annual Crude Rate       23.0  ...          46     CAN
# 52545  Average Annual Age-adjusted Rate        NaN  ...          51     CAN
# 52547         Average Annual Crude Rate       18.4  ...          53     CAN
# 52548         Average Annual Crude Rate       19.1  ...          54     CAN
# 52555  Average Annual Age-adjusted Rate        NaN  ...          49     CAN
#
#       QuestionID   DataValueTypeID  StratificationCategoryID1  \
# 76       CAN11_2     AVGANNCRDRATE                       RACE
# 77       CAN11_2        AVGANNNMBR                     GENDER
# 78       CAN11_2     AVGANNCRDRATE                       RACE
# 79       CAN11_2        AVGANNNMBR                     GENDER
# 80       CAN11_2        AVGANNNMBR                     GENDER
# ...          ...               ...                        ...
# 52536    CAN11_2     AVGANNCRDRATE                       RACE
# 52545    CAN11_2  AVGANNAGEADJRATE                       RACE
# 52547    CAN11_2     AVGANNCRDRATE                    OVERALL
# 52548    CAN11_2     AVGANNCRDRATE                     GENDER
# 52555    CAN11_2  AVGANNAGEADJRATE                       RACE
#
#       StratificationID1 StratificationCategoryID2  StratificationID2  \
# 76                  HIS                       NaN                NaN
# 77                 GENM                       NaN                NaN
# 78                 APIO                       NaN                NaN
# 79                 GENM                       NaN                NaN
# 80                 GENM                       NaN                NaN
# ...                 ...                       ...                ...
# 52536               WHT                       NaN                NaN
# 52545              AIAO                       NaN                NaN
# 52547               OVR                       NaN                NaN
# 52548              GENM                       NaN                NaN
# 52555               BLK                       NaN                NaN
#
#        StratificationCategoryID3  StratificationID3
# 76                           NaN                NaN
# 77                           NaN                NaN
# 78                           NaN                NaN
# 79                           NaN                NaN
# 80                           NaN                NaN
# ...                          ...                ...
# 52536                        NaN                NaN
# 52545                        NaN                NaN
# 52547                        NaN                NaN
# 52548                        NaN                NaN
# 52555                        NaN                NaN
#
# [9984 rows x 32 columns]

# %%
desired_records.drop(columns=['StratificationCategoryID2' ,'StratificationID3', 'StratificationID2' ,'StratificationCategoryID3', 'StratificationCategory2','Stratification2', 'StratificationCategory3','Stratification3','ResponseID'], inplace= True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_856\2101982136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desired_records.drop(columns=['StratificationCategoryID2' ,'StratificationID3', 'StratificationID2' ,'StratificationCategoryID3', 'StratificationCategory2','Stratification2', 'StratificationCategory3','Stratification3','ResponseID'], inplace= True)

# %%
desired_records.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'DataValueFootnoteSymbol', 'DatavalueFootnote',
#        'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory1',
#        'Stratification1', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')

# %%
desired_records
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc         DataSource  \
# 76          2013     2017           CA     California  Death Certificate
# 77          2014     2018           CA     California  Death Certificate
# 78          2010     2014           CO       Colorado  Death Certificate
# 79          2008     2012           FL        Florida  Death Certificate
# 80          2008     2012           GA        Georgia  Death Certificate
# ...          ...      ...          ...            ...                ...
# 52536       2009     2013           SD   South Dakota  Death Certificate
# 52545       2008     2012           VA       Virginia  Death Certificate
# 52547       2008     2012           WA     Washington  Death Certificate
# 52548       2011     2015           WV  West Virginia  Death Certificate
# 52555       2014     2018           UT           Utah  Death Certificate
#
#         Topic                           Question DataValueUnit  \
# 76     Cancer  Cancer of the prostate, mortality   per 100,000
# 77     Cancer  Cancer of the prostate, mortality           NaN
# 78     Cancer  Cancer of the prostate, mortality   per 100,000
# 79     Cancer  Cancer of the prostate, mortality           NaN
# 80     Cancer  Cancer of the prostate, mortality           NaN
# ...       ...                                ...           ...
# 52536  Cancer  Cancer of the prostate, mortality   per 100,000
# 52545  Cancer  Cancer of the prostate, mortality   per 100,000
# 52547  Cancer  Cancer of the prostate, mortality   per 100,000
# 52548  Cancer  Cancer of the prostate, mortality   per 100,000
# 52555  Cancer  Cancer of the prostate, mortality   per 100,000
#
#                           DataValueType  DataValue  ...  LowConfidenceLimit  \
# 76            Average Annual Crude Rate        7.1  ...                 6.8
# 77                Average Annual Number     3469.0  ...                 NaN
# 78            Average Annual Crude Rate        4.6  ...                 2.8
# 79                Average Annual Number     2086.0  ...                 NaN
# 80                Average Annual Number      750.0  ...                 NaN
# ...                                 ...        ...  ...                 ...
# 52536         Average Annual Crude Rate       23.0  ...                20.9
# 52545  Average Annual Age-adjusted Rate        NaN  ...                 NaN
# 52547         Average Annual Crude Rate       18.4  ...                17.8
# 52548         Average Annual Crude Rate       19.1  ...                17.9
# 52555  Average Annual Age-adjusted Rate        NaN  ...                 NaN
#
#       HighConfidenceLimit StratificationCategory1  \
# 76                    7.3          Race/Ethnicity
# 77                    NaN                  Gender
# 78                    7.2          Race/Ethnicity
# 79                    NaN                  Gender
# 80                    NaN                  Gender
# ...                   ...                     ...
# 52536                25.4          Race/Ethnicity
# 52545                 NaN          Race/Ethnicity
# 52547                19.1                 Overall
# 52548                20.4                  Gender
# 52555                 NaN          Race/Ethnicity
#
#                         Stratification1  LocationID TopicID QuestionID  \
# 76                             Hispanic           6     CAN    CAN11_2
# 77                                 Male           6     CAN    CAN11_2
# 78            Asian or Pacific Islander           8     CAN    CAN11_2
# 79                                 Male          12     CAN    CAN11_2
# 80                                 Male          13     CAN    CAN11_2
# ...                                 ...         ...     ...        ...
# 52536               White, non-Hispanic          46     CAN    CAN11_2
# 52545  American Indian or Alaska Native          51     CAN    CAN11_2
# 52547                           Overall          53     CAN    CAN11_2
# 52548                              Male          54     CAN    CAN11_2
# 52555               Black, non-Hispanic          49     CAN    CAN11_2
#
#         DataValueTypeID StratificationCategoryID1 StratificationID1
# 76        AVGANNCRDRATE                      RACE               HIS
# 77           AVGANNNMBR                    GENDER              GENM
# 78        AVGANNCRDRATE                      RACE              APIO
# 79           AVGANNNMBR                    GENDER              GENM
# 80           AVGANNNMBR                    GENDER              GENM
# ...                 ...                       ...               ...
# 52536     AVGANNCRDRATE                      RACE               WHT
# 52545  AVGANNAGEADJRATE                      RACE              AIAO
# 52547     AVGANNCRDRATE                   OVERALL               OVR
# 52548     AVGANNCRDRATE                    GENDER              GENM
# 52555  AVGANNAGEADJRATE                      RACE               BLK
#
# [9984 rows x 23 columns]

# %%
#counting the NaN records to see if they affect the data
nan_counts = desired_records.isna().sum()

# %%
nan_counts
# Out:
# YearStart                       0
# YearEnd                         0
# LocationAbbr                    0
# LocationDesc                    0
# DataSource                      0
# Topic                           0
# Question                        0
# DataValueUnit                3328
# DataValueType                   0
# DataValue                    3951
# DataValueAlt                 3951
# DataValueFootnoteSymbol      6033
# DatavalueFootnote            6033
# LowConfidenceLimit           5962
# HighConfidenceLimit          5962
# StratificationCategory1         0
# Stratification1                 0
# LocationID                      0
# TopicID                         0
# QuestionID                      0
# DataValueTypeID                 0
# StratificationCategoryID1       0
# StratificationID1               0
# dtype: int64

# %%
#differenctiating records according to race and gender
gender_data = desired_records[desired_records["StratificationCategoryID1"] == 'GENDER']

# %%
gender_data
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc         DataSource  \
# 77          2014     2018           CA     California  Death Certificate
# 79          2008     2012           FL        Florida  Death Certificate
# 80          2008     2012           GA        Georgia  Death Certificate
# 83          2008     2012           ID          Idaho  Death Certificate
# 85          2010     2014           ID          Idaho  Death Certificate
# ...          ...      ...          ...            ...                ...
# 52488       2010     2014           TX          Texas  Death Certificate
# 52491       2008     2012           TX          Texas  Death Certificate
# 52520       2015     2019           SD   South Dakota  Death Certificate
# 52523       2013     2017           WV  West Virginia  Death Certificate
# 52548       2011     2015           WV  West Virginia  Death Certificate
#
#         Topic                           Question DataValueUnit  \
# 77     Cancer  Cancer of the prostate, mortality           NaN
# 79     Cancer  Cancer of the prostate, mortality           NaN
# 80     Cancer  Cancer of the prostate, mortality           NaN
# 83     Cancer  Cancer of the prostate, mortality   per 100,000
# 85     Cancer  Cancer of the prostate, mortality           NaN
# ...       ...                                ...           ...
# 52488  Cancer  Cancer of the prostate, mortality   per 100,000
# 52491  Cancer  Cancer of the prostate, mortality   per 100,000
# 52520  Cancer  Cancer of the prostate, mortality   per 100,000
# 52523  Cancer  Cancer of the prostate, mortality   per 100,000
# 52548  Cancer  Cancer of the prostate, mortality   per 100,000
#
#                    DataValueType  DataValue  ...  LowConfidenceLimit  \
# 77         Average Annual Number     3469.0  ...                 NaN
# 79         Average Annual Number     2086.0  ...                 NaN
# 80         Average Annual Number      750.0  ...                 NaN
# 83     Average Annual Crude Rate       20.4  ...                19.0
# 85         Average Annual Number      164.0  ...                 NaN
# ...                          ...        ...  ...                 ...
# 52488  Average Annual Crude Rate        NaN  ...                 NaN
# 52491  Average Annual Crude Rate       12.9  ...                12.7
# 52520  Average Annual Crude Rate        NaN  ...                 NaN
# 52523  Average Annual Crude Rate        NaN  ...                 NaN
# 52548  Average Annual Crude Rate       19.1  ...                17.9
#
#       HighConfidenceLimit StratificationCategory1  Stratification1  \
# 77                    NaN                  Gender             Male
# 79                    NaN                  Gender             Male
# 80                    NaN                  Gender             Male
# 83                   21.9                  Gender             Male
# 85                    NaN                  Gender             Male
# ...                   ...                     ...              ...
# 52488                 NaN                  Gender           Female
# 52491                13.2                  Gender             Male
# 52520                 NaN                  Gender           Female
# 52523                 NaN                  Gender           Female
# 52548                20.4                  Gender             Male
#
#        LocationID TopicID QuestionID  DataValueTypeID  \
# 77              6     CAN    CAN11_2       AVGANNNMBR
# 79             12     CAN    CAN11_2       AVGANNNMBR
# 80             13     CAN    CAN11_2       AVGANNNMBR
# 83             16     CAN    CAN11_2    AVGANNCRDRATE
# 85             16     CAN    CAN11_2       AVGANNNMBR
# ...           ...     ...        ...              ...
# 52488          48     CAN    CAN11_2    AVGANNCRDRATE
# 52491          48     CAN    CAN11_2    AVGANNCRDRATE
# 52520          46     CAN    CAN11_2    AVGANNCRDRATE
# 52523          54     CAN    CAN11_2    AVGANNCRDRATE
# 52548          54     CAN    CAN11_2    AVGANNCRDRATE
#
#       StratificationCategoryID1 StratificationID1
# 77                       GENDER              GENM
# 79                       GENDER              GENM
# 80                       GENDER              GENM
# 83                       GENDER              GENM
# 85                       GENDER              GENM
# ...                         ...               ...
# 52488                    GENDER              GENF
# 52491                    GENDER              GENM
# 52520                    GENDER              GENF
# 52523                    GENDER              GENF
# 52548                    GENDER              GENM
#
# [2496 rows x 23 columns]

# %%
#to see the unique genders used in dataset
unique_gender = gender_data['Stratification1'].unique()

# %%
unique_gender
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
gender_data['DataSource'].unique()
# Out:
# array(['Death Certificate'], dtype=object)

# %%
gender_data.sort_values(by='YearStart' , inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_856\804311705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gender_data.sort_values(by='YearStart' , inplace = True)

# %%
gender_data
# Out:
#        YearStart  YearEnd LocationAbbr  LocationDesc         DataSource  \
# 27070       2008     2012           ME         Maine  Death Certificate
# 30679       2008     2012           IL      Illinois  Death Certificate
# 27287       2008     2012           KY      Kentucky  Death Certificate
# 33226       2008     2012           NY      New York  Death Certificate
# 27263       2008     2012           DE      Delaware  Death Certificate
# ...          ...      ...          ...           ...                ...
# 30658       2015     2019           RI  Rhode Island  Death Certificate
# 30680       2015     2019           FL       Florida  Death Certificate
# 30704       2015     2019           AZ       Arizona  Death Certificate
# 30458       2015     2019           CT   Connecticut  Death Certificate
# 29386       2015     2019           RI  Rhode Island  Death Certificate
#
#         Topic                           Question DataValueUnit  \
# 27070  Cancer  Cancer of the prostate, mortality   per 100,000
# 30679  Cancer  Cancer of the prostate, mortality   per 100,000
# 27287  Cancer  Cancer of the prostate, mortality           NaN
# 33226  Cancer  Cancer of the prostate, mortality   per 100,000
# 27263  Cancer  Cancer of the prostate, mortality   per 100,000
# ...       ...                                ...           ...
# 30658  Cancer  Cancer of the prostate, mortality   per 100,000
# 30680  Cancer  Cancer of the prostate, mortality           NaN
# 30704  Cancer  Cancer of the prostate, mortality   per 100,000
# 30458  Cancer  Cancer of the prostate, mortality   per 100,000
# 29386  Cancer  Cancer of the prostate, mortality   per 100,000
#
#                           DataValueType  DataValue  ...  LowConfidenceLimit  \
# 27070         Average Annual Crude Rate        NaN  ...                 NaN
# 30679         Average Annual Crude Rate       18.4  ...                18.0
# 27287             Average Annual Number      373.0  ...                 NaN
# 33226  Average Annual Age-adjusted Rate       20.6  ...                20.1
# 27263  Average Annual Age-adjusted Rate       22.5  ...                20.5
# ...                                 ...        ...  ...                 ...
# 30658  Average Annual Age-adjusted Rate        NaN  ...                 NaN
# 30680             Average Annual Number        NaN  ...                 NaN
# 30704  Average Annual Age-adjusted Rate        NaN  ...                 NaN
# 30458         Average Annual Crude Rate        NaN  ...                 NaN
# 29386         Average Annual Crude Rate       19.9  ...                18.2
#
#       HighConfidenceLimit StratificationCategory1  Stratification1  \
# 27070                 NaN                  Gender           Female
# 30679                18.9                  Gender             Male
# 27287                 NaN                  Gender             Male
# 33226                21.0                  Gender             Male
# 27263                24.7                  Gender             Male
# ...                   ...                     ...              ...
# 30658                 NaN                  Gender           Female
# 30680                 NaN                  Gender           Female
# 30704                 NaN                  Gender           Female
# 30458                 NaN                  Gender           Female
# 29386                21.7                  Gender             Male
#
#        LocationID TopicID QuestionID   DataValueTypeID  \
# 27070          23     CAN    CAN11_2     AVGANNCRDRATE
# 30679          17     CAN    CAN11_2     AVGANNCRDRATE
# 27287          21     CAN    CAN11_2        AVGANNNMBR
# 33226          36     CAN    CAN11_2  AVGANNAGEADJRATE
# 27263          10     CAN    CAN11_2  AVGANNAGEADJRATE
# ...           ...     ...        ...               ...
# 30658          44     CAN    CAN11_2  AVGANNAGEADJRATE
# 30680          12     CAN    CAN11_2        AVGANNNMBR
# 30704           4     CAN    CAN11_2  AVGANNAGEADJRATE
# 30458           9     CAN    CAN11_2     AVGANNCRDRATE
# 29386          44     CAN    CAN11_2     AVGANNCRDRATE
#
#       StratificationCategoryID1 StratificationID1
# 27070                    GENDER              GENF
# 30679                    GENDER              GENM
# 27287                    GENDER              GENM
# 33226                    GENDER              GENM
# 27263                    GENDER              GENM
# ...                         ...               ...
# 30658                    GENDER              GENF
# 30680                    GENDER              GENF
# 30704                    GENDER              GENF
# 30458                    GENDER              GENF
# 29386                    GENDER              GENM
#
# [2496 rows x 23 columns]

# %%
crude_data= gender_data[gender_data["DataValueType"] == 'Average Annual Crude Rate']

# %%
#renaming the columns for simplicity
crude_data.rename(columns={'YearEnd': 'Year', 'LocationDesc': 'Location', 'Question': 'Theme', 'DataValueType': 'Method', 'DataValue': 'Value', 'Stratification1' : 'Gender'}, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_856\1940416843.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crude_data.rename(columns={'YearEnd': 'Year', 'LocationDesc': 'Location', 'Question': 'Theme', 'DataValueType': 'Method', 'DataValue': 'Value', 'Stratification1' : 'Gender'}, inplace=True)

# %%
crude_data.columns
# Out:
# Index(['YearStart', 'Year', 'LocationAbbr', 'Location', 'DataSource', 'Topic',
#        'Theme', 'DataValueUnit', 'Method', 'Value', 'DataValueAlt',
#        'DataValueFootnoteSymbol', 'DatavalueFootnote', 'LowConfidenceLimit',
#        'HighConfidenceLimit', 'StratificationCategory1', 'Gender',
#        'LocationID', 'TopicID', 'QuestionID', 'DataValueTypeID',
#        'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')

# %%
crude_data
# Out:
#        YearStart  Year LocationAbbr              Location         DataSource  \
# 27070       2008  2012           ME                 Maine  Death Certificate
# 30679       2008  2012           IL              Illinois  Death Certificate
# 43793       2008  2012           TN             Tennessee  Death Certificate
# 27124       2008  2012           OK              Oklahoma  Death Certificate
# 27096       2008  2012           RI          Rhode Island  Death Certificate
# ...          ...   ...          ...                   ...                ...
# 30416       2015  2019           MD              Maryland  Death Certificate
# 30456       2015  2019           DC  District of Columbia  Death Certificate
# 30470       2015  2019           AZ               Arizona  Death Certificate
# 30458       2015  2019           CT           Connecticut  Death Certificate
# 29386       2015  2019           RI          Rhode Island  Death Certificate
#
#         Topic                              Theme DataValueUnit  \
# 27070  Cancer  Cancer of the prostate, mortality   per 100,000
# 30679  Cancer  Cancer of the prostate, mortality   per 100,000
# 43793  Cancer  Cancer of the prostate, mortality   per 100,000
# 27124  Cancer  Cancer of the prostate, mortality   per 100,000
# 27096  Cancer  Cancer of the prostate, mortality   per 100,000
# ...       ...                                ...           ...
# 30416  Cancer  Cancer of the prostate, mortality   per 100,000
# 30456  Cancer  Cancer of the prostate, mortality   per 100,000
# 30470  Cancer  Cancer of the prostate, mortality   per 100,000
# 30458  Cancer  Cancer of the prostate, mortality   per 100,000
# 29386  Cancer  Cancer of the prostate, mortality   per 100,000
#
#                           Method  Value  ...  LowConfidenceLimit  \
# 27070  Average Annual Crude Rate    NaN  ...                 NaN
# 30679  Average Annual Crude Rate   18.4  ...                18.0
# 43793  Average Annual Crude Rate    NaN  ...                 NaN
# 27124  Average Annual Crude Rate   19.5  ...                18.6
# 27096  Average Annual Crude Rate   20.9  ...                19.1
# ...                          ...    ...  ...                 ...
# 30416  Average Annual Crude Rate    NaN  ...                 NaN
# 30456  Average Annual Crude Rate    NaN  ...                 NaN
# 30470  Average Annual Crude Rate   19.6  ...                19.0
# 30458  Average Annual Crude Rate    NaN  ...                 NaN
# 29386  Average Annual Crude Rate   19.9  ...                18.2
#
#       HighConfidenceLimit StratificationCategory1  Gender  LocationID TopicID  \
# 27070                 NaN                  Gender  Female          23     CAN
# 30679                18.9                  Gender    Male          17     CAN
# 43793                 NaN                  Gender  Female          47     CAN
# 27124                20.4                  Gender    Male          40     CAN
# 27096                22.7                  Gender    Male          44     CAN
# ...                   ...                     ...     ...         ...     ...
# 30416                 NaN                  Gender  Female          24     CAN
# 30456                 NaN                  Gender  Female          11     CAN
# 30470                20.3                  Gender    Male           4     CAN
# 30458                 NaN                  Gender  Female           9     CAN
# 29386                21.7                  Gender    Male          44     CAN
#
#       QuestionID  DataValueTypeID StratificationCategoryID1 StratificationID1
# 27070    CAN11_2    AVGANNCRDRATE                    GENDER              GENF
# 30679    CAN11_2    AVGANNCRDRATE                    GENDER              GENM
# 43793    CAN11_2    AVGANNCRDRATE                    GENDER              GENF
# 27124    CAN11_2    AVGANNCRDRATE                    GENDER              GENM
# 27096    CAN11_2    AVGANNCRDRATE                    GENDER              GENM
# ...          ...              ...                       ...               ...
# 30416    CAN11_2    AVGANNCRDRATE                    GENDER              GENF
# 30456    CAN11_2    AVGANNCRDRATE                    GENDER              GENF
# 30470    CAN11_2    AVGANNCRDRATE                    GENDER              GENM
# 30458    CAN11_2    AVGANNCRDRATE                    GENDER              GENF
# 29386    CAN11_2    AVGANNCRDRATE                    GENDER              GENM
#
# [832 rows x 23 columns]

# %%
final_data = crude_data[["Year", "Location", "Theme", "Method", "Value", "Gender"]].copy()

# %%
final_data
# Out:
#        Year              Location                              Theme  \
# 27070  2012                 Maine  Cancer of the prostate, mortality
# 30679  2012              Illinois  Cancer of the prostate, mortality
# 43793  2012             Tennessee  Cancer of the prostate, mortality
# 27124  2012              Oklahoma  Cancer of the prostate, mortality
# 27096  2012          Rhode Island  Cancer of the prostate, mortality
# ...     ...                   ...                                ...
# 30416  2019              Maryland  Cancer of the prostate, mortality
# 30456  2019  District of Columbia  Cancer of the prostate, mortality
# 30470  2019               Arizona  Cancer of the prostate, mortality
# 30458  2019           Connecticut  Cancer of the prostate, mortality
# 29386  2019          Rhode Island  Cancer of the prostate, mortality
#
#                           Method  Value  Gender
# 27070  Average Annual Crude Rate    NaN  Female
# 30679  Average Annual Crude Rate   18.4    Male
# 43793  Average Annual Crude Rate    NaN  Female
# 27124  Average Annual Crude Rate   19.5    Male
# 27096  Average Annual Crude Rate   20.9    Male
# ...                          ...    ...     ...
# 30416  Average Annual Crude Rate    NaN  Female
# 30456  Average Annual Crude Rate    NaN  Female
# 30470  Average Annual Crude Rate   19.6    Male
# 30458  Average Annual Crude Rate    NaN  Female
# 29386  Average Annual Crude Rate   19.9    Male
#
# [832 rows x 6 columns]

# %%
final_data['Value'].isna().sum()
# Out:
# 416

# %% [markdown]
# SO, here we got 416 records out of 832 with NaN values : all females, for Annual crude rate. let's check if
# other method such as Average Annual Number has lesser NaN.

# %%
#now we create another dataframe with respect to average annual number to count the NaN values.
number_data= gender_data[gender_data["DataValueType"] == 'Average Annual Number']

# %%
number_data
#sucessfully created a new DF
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc         DataSource  \
# 27287       2008     2012           KY       Kentucky  Death Certificate
# 27239       2008     2012           OR         Oregon  Death Certificate
# 40343       2008     2012           WY        Wyoming  Death Certificate
# 30750       2008     2012           MS    Mississippi  Death Certificate
# 40255       2008     2012           WA     Washington  Death Certificate
# ...          ...      ...          ...            ...                ...
# 31102       2015     2019           MN      Minnesota  Death Certificate
# 30828       2015     2019           NH  New Hampshire  Death Certificate
# 35480       2015     2019           LA      Louisiana  Death Certificate
# 35573       2015     2019           RI   Rhode Island  Death Certificate
# 30680       2015     2019           FL        Florida  Death Certificate
#
#         Topic                           Question DataValueUnit  \
# 27287  Cancer  Cancer of the prostate, mortality           NaN
# 27239  Cancer  Cancer of the prostate, mortality           NaN
# 40343  Cancer  Cancer of the prostate, mortality           NaN
# 30750  Cancer  Cancer of the prostate, mortality           NaN
# 40255  Cancer  Cancer of the prostate, mortality           NaN
# ...       ...                                ...           ...
# 31102  Cancer  Cancer of the prostate, mortality           NaN
# 30828  Cancer  Cancer of the prostate, mortality           NaN
# 35480  Cancer  Cancer of the prostate, mortality           NaN
# 35573  Cancer  Cancer of the prostate, mortality           NaN
# 30680  Cancer  Cancer of the prostate, mortality           NaN
#
#                DataValueType  DataValue  ...  LowConfidenceLimit  \
# 27287  Average Annual Number      373.0  ...                 NaN
# 27239  Average Annual Number        NaN  ...                 NaN
# 40343  Average Annual Number        NaN  ...                 NaN
# 30750  Average Annual Number      326.0  ...                 NaN
# 40255  Average Annual Number        NaN  ...                 NaN
# ...                      ...        ...  ...                 ...
# 31102  Average Annual Number        NaN  ...                 NaN
# 30828  Average Annual Number        NaN  ...                 NaN
# 35480  Average Annual Number        NaN  ...                 NaN
# 35573  Average Annual Number        NaN  ...                 NaN
# 30680  Average Annual Number        NaN  ...                 NaN
#
#       HighConfidenceLimit StratificationCategory1  Stratification1  \
# 27287                 NaN                  Gender             Male
# 27239                 NaN                  Gender           Female
# 40343                 NaN                  Gender           Female
# 30750                 NaN                  Gender             Male
# 40255                 NaN                  Gender           Female
# ...                   ...                     ...              ...
# 31102                 NaN                  Gender           Female
# 30828                 NaN                  Gender           Female
# 35480                 NaN                  Gender           Female
# 35573                 NaN                  Gender           Female
# 30680                 NaN                  Gender           Female
#
#        LocationID TopicID QuestionID  DataValueTypeID  \
# 27287          21     CAN    CAN11_2       AVGANNNMBR
# 27239          41     CAN    CAN11_2       AVGANNNMBR
# 40343          56     CAN    CAN11_2       AVGANNNMBR
# 30750          28     CAN    CAN11_2       AVGANNNMBR
# 40255          53     CAN    CAN11_2       AVGANNNMBR
# ...           ...     ...        ...              ...
# 31102          27     CAN    CAN11_2       AVGANNNMBR
# 30828          33     CAN    CAN11_2       AVGANNNMBR
# 35480          22     CAN    CAN11_2       AVGANNNMBR
# 35573          44     CAN    CAN11_2       AVGANNNMBR
# 30680          12     CAN    CAN11_2       AVGANNNMBR
#
#       StratificationCategoryID1 StratificationID1
# 27287                    GENDER              GENM
# 27239                    GENDER              GENF
# 40343                    GENDER              GENF
# 30750                    GENDER              GENM
# 40255                    GENDER              GENF
# ...                         ...               ...
# 31102                    GENDER              GENF
# 30828                    GENDER              GENF
# 35480                    GENDER              GENF
# 35573                    GENDER              GENF
# 30680                    GENDER              GENF
#
# [832 rows x 23 columns]

# %%
#Na values counting
number_data['DataValue'].isna().sum()
# Out:
# 416

# %% [markdown]
# So the NaN count with this data collection method is also similar. hence, we will proceed with the average crude rate method for further analysis.

# %%
final_data
#calling out final data for further analysis
# Out:
#        Year              Location                              Theme  \
# 27070  2012                 Maine  Cancer of the prostate, mortality
# 30679  2012              Illinois  Cancer of the prostate, mortality
# 43793  2012             Tennessee  Cancer of the prostate, mortality
# 27124  2012              Oklahoma  Cancer of the prostate, mortality
# 27096  2012          Rhode Island  Cancer of the prostate, mortality
# ...     ...                   ...                                ...
# 30416  2019              Maryland  Cancer of the prostate, mortality
# 30456  2019  District of Columbia  Cancer of the prostate, mortality
# 30470  2019               Arizona  Cancer of the prostate, mortality
# 30458  2019           Connecticut  Cancer of the prostate, mortality
# 29386  2019          Rhode Island  Cancer of the prostate, mortality
#
#                           Method  Value  Gender
# 27070  Average Annual Crude Rate    NaN  Female
# 30679  Average Annual Crude Rate   18.4    Male
# 43793  Average Annual Crude Rate    NaN  Female
# 27124  Average Annual Crude Rate   19.5    Male
# 27096  Average Annual Crude Rate   20.9    Male
# ...                          ...    ...     ...
# 30416  Average Annual Crude Rate    NaN  Female
# 30456  Average Annual Crude Rate    NaN  Female
# 30470  Average Annual Crude Rate   19.6    Male
# 30458  Average Annual Crude Rate    NaN  Female
# 29386  Average Annual Crude Rate   19.9    Male
#
# [832 rows x 6 columns]

# %%
#dropping na values from 'Value' column now
#pd.set_option('display.max_rows', None)  # Show all rows
#pd.set_option('display.max_columns', None)  # Show all columns

final_data = final_data.dropna(subset=['Value'])
final_data
# Out:
#        Year      Location                              Theme  \
# 30679  2012      Illinois  Cancer of the prostate, mortality
# 27124  2012      Oklahoma  Cancer of the prostate, mortality
# 27096  2012  Rhode Island  Cancer of the prostate, mortality
# 36442  2012         Maine  Cancer of the prostate, mortality
# 36501  2012       Georgia  Cancer of the prostate, mortality
# ...     ...           ...                                ...
# 41386  2019  South Dakota  Cancer of the prostate, mortality
# 28921  2019       Georgia  Cancer of the prostate, mortality
# 40945  2019       Wyoming  Cancer of the prostate, mortality
# 30470  2019       Arizona  Cancer of the prostate, mortality
# 29386  2019  Rhode Island  Cancer of the prostate, mortality
#
#                           Method  Value Gender
# 30679  Average Annual Crude Rate   18.4   Male
# 27124  Average Annual Crude Rate   19.5   Male
# 27096  Average Annual Crude Rate   20.9   Male
# 36442  Average Annual Crude Rate   22.1   Male
# 36501  Average Annual Crude Rate   15.8   Male
# ...                          ...    ...    ...
# 41386  Average Annual Crude Rate   20.3   Male
# 28921  Average Annual Crude Rate   17.7   Male
# 40945  Average Annual Crude Rate   17.6   Male
# 30470  Average Annual Crude Rate   19.6   Male
# 29386  Average Annual Crude Rate   19.9   Male
#
# [416 rows x 6 columns]

# %% [markdown]
# so now we have list of the territories of USA and also the average of the whole United States of America according to the year from 2008 to 2015.

# %%
#lets find out the average mortality rate for all states and then we'll take top 5 states


# Calculate average mortality rates for each state
average_mortality_rates = final_data.groupby('Location')['Value'].mean()

# Sort states by average mortality rate in descending order
sorted_states = average_mortality_rates.sort_values(ascending=False)

sorted_states
# Out:
# Location
# Montana                 24.0375
# District of Columbia    23.6250
# Maine                   23.3750
# Mississippi             22.5625
# Florida                 22.4875
# Oregon                  21.8875
# Vermont                 21.6250
# Pennsylvania            21.5125
# Wisconsin               21.3125
# Iowa                    21.2000
# Alabama                 21.2000
# South Carolina          21.1375
# Idaho                   21.1000
# Rhode Island            20.2250
# South Dakota            20.0500
# West Virginia           19.9625
# Ohio                    19.9500
# New Hampshire           19.7375
# Arkansas                19.6500
# New Mexico              19.5500
# North Dakota            19.4875
# Minnesota               19.4375
# Delaware                19.4250
# Oklahoma                19.3250
# Connecticut             19.2750
# Nebraska                19.1500
# Michigan                19.1250
# Massachusetts           18.9125
# Louisiana               18.6000
# Illinois                18.5750
# Tennessee               18.5750
# Arizona                 18.5000
# North Carolina          18.4875
# United States           18.4250
# Indiana                 18.3000
# Washington              18.2625
# Maryland                18.2125
# New York                18.1750
# Kansas                  18.0625
# Missouri                18.0375
# New Jersey              17.8750
# Kentucky                17.5125
# Nevada                  17.5000
# Virginia                17.4750
# California              17.0250
# Colorado                16.7375
# Georgia                 16.5250
# Wyoming                 15.9875
# Hawaii                  15.8000
# Utah                    13.8500
# Texas                   13.1500
# Alaska                  10.8625
# Name: Value, dtype: float64

# %% [markdown]
# Now, we have the list of territories with highest mortality rate to lowest. so we'll be selecting only the top 5 territories for our analysis i.e Montana, DIstrict of columbia, maine, Mississipipi and Florida

# %% [markdown]
# Now, lets create a new data frame to store these 5 states' data for their trend visualisation. Furthermore we can plot a bar chart for the average mortality rate with the above data now too.

# %%
Territories = ['Montana', 'District of Columbia', 'Maine', 'Mississipipi', 'Florida']
filtered_records = final_data[final_data["Location"].isin(Territories)]

# %%
filtered_records
# Out:
#        Year              Location                              Theme  \
# 36442  2012                 Maine  Cancer of the prostate, mortality
# 36090  2012               Florida  Cancer of the prostate, mortality
# 34399  2012               Montana  Cancer of the prostate, mortality
# 35673  2012  District of Columbia  Cancer of the prostate, mortality
# 30269  2013  District of Columbia  Cancer of the prostate, mortality
# 34124  2013                 Maine  Cancer of the prostate, mortality
# 33705  2013               Florida  Cancer of the prostate, mortality
# 26422  2013               Montana  Cancer of the prostate, mortality
# 32178  2014               Florida  Cancer of the prostate, mortality
# 33165  2014  District of Columbia  Cancer of the prostate, mortality
# 31579  2014               Montana  Cancer of the prostate, mortality
# 92     2014                 Maine  Cancer of the prostate, mortality
# 36288  2015               Florida  Cancer of the prostate, mortality
# 32923  2015  District of Columbia  Cancer of the prostate, mortality
# 30485  2015               Montana  Cancer of the prostate, mortality
# 93     2015                 Maine  Cancer of the prostate, mortality
# 38260  2016  District of Columbia  Cancer of the prostate, mortality
# 28785  2016               Montana  Cancer of the prostate, mortality
# 36224  2016                 Maine  Cancer of the prostate, mortality
# 31970  2016               Florida  Cancer of the prostate, mortality
# 31830  2017                 Maine  Cancer of the prostate, mortality
# 28119  2017               Montana  Cancer of the prostate, mortality
# 36527  2017  District of Columbia  Cancer of the prostate, mortality
# 33369  2017               Florida  Cancer of the prostate, mortality
# 33000  2018               Montana  Cancer of the prostate, mortality
# 29267  2018               Florida  Cancer of the prostate, mortality
# 26460  2018  District of Columbia  Cancer of the prostate, mortality
# 27854  2018                 Maine  Cancer of the prostate, mortality
# 36614  2019                 Maine  Cancer of the prostate, mortality
# 38313  2019               Florida  Cancer of the prostate, mortality
# 31922  2019  District of Columbia  Cancer of the prostate, mortality
# 34661  2019               Montana  Cancer of the prostate, mortality
#
#                           Method  Value Gender
# 36442  Average Annual Crude Rate   22.1   Male
# 36090  Average Annual Crude Rate   22.6   Male
# 34399  Average Annual Crude Rate   23.9   Male
# 35673  Average Annual Crude Rate   25.9   Male
# 30269  Average Annual Crude Rate   26.5   Male
# 34124  Average Annual Crude Rate   22.8   Male
# 33705  Average Annual Crude Rate   22.4   Male
# 26422  Average Annual Crude Rate   23.4   Male
# 32178  Average Annual Crude Rate   22.3   Male
# 33165  Average Annual Crude Rate   25.0   Male
# 31579  Average Annual Crude Rate   22.8   Male
# 92     Average Annual Crude Rate   22.1   Male
# 36288  Average Annual Crude Rate   22.2   Male
# 32923  Average Annual Crude Rate   24.0   Male
# 30485  Average Annual Crude Rate   22.1   Male
# 93     Average Annual Crude Rate   22.6   Male
# 38260  Average Annual Crude Rate   23.0   Male
# 28785  Average Annual Crude Rate   23.3   Male
# 36224  Average Annual Crude Rate   23.6   Male
# 31970  Average Annual Crude Rate   22.1   Male
# 31830  Average Annual Crude Rate   24.8   Male
# 28119  Average Annual Crude Rate   25.4   Male
# 36527  Average Annual Crude Rate   21.5   Male
# 33369  Average Annual Crude Rate   22.5   Male
# 33000  Average Annual Crude Rate   25.5   Male
# 29267  Average Annual Crude Rate   22.8   Male
# 26460  Average Annual Crude Rate   22.0   Male
# 27854  Average Annual Crude Rate   24.1   Male
# 36614  Average Annual Crude Rate   24.9   Male
# 38313  Average Annual Crude Rate   23.0   Male
# 31922  Average Annual Crude Rate   21.1   Male
# 34661  Average Annual Crude Rate   25.9   Male

# %%
import matplotlib.pyplot as plt

df_pivot = filtered_records.pivot(index='Year', columns='Location', values='Value')

ax = df_pivot.plot(kind='bar')
ax.set_xlabel('Year')
ax.set_ylabel('Average Crude Rates')
plt.show()

# %%
final_data
# Out:
#        Year      Location                              Theme  \
# 30679  2012      Illinois  Cancer of the prostate, mortality
# 27124  2012      Oklahoma  Cancer of the prostate, mortality
# 27096  2012  Rhode Island  Cancer of the prostate, mortality
# 36442  2012         Maine  Cancer of the prostate, mortality
# 36501  2012       Georgia  Cancer of the prostate, mortality
# ...     ...           ...                                ...
# 41386  2019  South Dakota  Cancer of the prostate, mortality
# 28921  2019       Georgia  Cancer of the prostate, mortality
# 40945  2019       Wyoming  Cancer of the prostate, mortality
# 30470  2019       Arizona  Cancer of the prostate, mortality
# 29386  2019  Rhode Island  Cancer of the prostate, mortality
#
#                           Method  Value Gender
# 30679  Average Annual Crude Rate   18.4   Male
# 27124  Average Annual Crude Rate   19.5   Male
# 27096  Average Annual Crude Rate   20.9   Male
# 36442  Average Annual Crude Rate   22.1   Male
# 36501  Average Annual Crude Rate   15.8   Male
# ...                          ...    ...    ...
# 41386  Average Annual Crude Rate   20.3   Male
# 28921  Average Annual Crude Rate   17.7   Male
# 40945  Average Annual Crude Rate   17.6   Male
# 30470  Average Annual Crude Rate   19.6   Male
# 29386  Average Annual Crude Rate   19.9   Male
#
# [416 rows x 6 columns]

# %%
#creating a data frame for the highest mortality state i.e.montana
df_montana = final_data[final_data['Location']=='Montana']
#creating a dataframe with just years and average value combined
df_montana_yearly = df_montana.groupby('Year')['Value'].sum()
df_montana_grouped = df_montana_yearly.reset_index()
df_montana_grouped
# Out:
#    Year  Value
# 0  2012   23.9
# 1  2013   23.4
# 2  2014   22.8
# 3  2015   22.1
# 4  2016   23.3
# 5  2017   25.4
# 6  2018   25.5
# 7  2019   25.9

# %%
#creating a line graph with red clor and dot marking
plt.plot(df_montana_grouped['Year'], df_montana_grouped['Value'], marker = 'o', color = 'red')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Mortality Rate')
plt.title('Prostate Cancer Mortality Rate Over Years(male)')

# Display the plot
plt.show()
